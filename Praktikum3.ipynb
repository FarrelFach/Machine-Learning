# %% [markdown]
# <a href="https://colab.research.google.com/github/FarrelFach/Machine-Learning/blob/main/Praktikum3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d5e28994-e1a4-425d-8406-ce051fc55b1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5e28994-e1a4-425d-8406-ce051fc55b1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# akshaydattatraykhare/diabetes-dataset                           Diabetes Dataset                                  9KB  2022-10-06 08:55:25           9736        311  1.0
# whenamancodes/covid-19-coronavirus-pandemic-dataset             COVID -19 Coronavirus Pandemic Dataset           11KB  2022-09-30 04:05:11           7809        248  1.0
# stetsondone/video-game-sales-by-genre                           Video Game Sales by Genre                        12KB  2022-10-31 17:56:01            418         23  1.0
# ...

# %%
# !kaggle datasets list -s "indonesia abusive"
# Out:
# ref                                                        title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ilhamfp31/indonesian-abusive-and-hate-speech-twitter-text  Indonesian Abusive and Hate Speech Twitter Text  814KB  2020-04-15 14:27:08           2455         50  0.9705882

# %%
# !kaggle datasets download -d ilhamfp31/indonesian-abusive-and-hate-speech-twitter-text
# Out:
# ...
# 100% 814k/814k [00:00<00:00, 1.28MB/s]
# 100% 814k/814k [00:00<00:00, 1.28MB/s]

# %%
# !unzip -d /content/batik/ indonesian-batik-motifs.zip
# Out:
# Archive:  indonesian-batik-motifs.zip
# replace /content/batik/batik-bali/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/batik/batik-bali/1.jpg
# replace /content/batik/batik-bali/10.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/batik/batik-bali/10.jpg
#   inflating: /content/batik/batik-bali/11.jpg
#   inflating: /content/batik/batik-bali/12.jpg
#   inflating: /content/batik/batik-bali/13.jpg
#   inflating: /content/batik/batik-bali/14.jpg
#   inflating: /content/batik/batik-bali/15.jpg
#   inflating: /content/batik/batik-bali/16.jpg
#   inflating: /content/batik/batik-bali/17.jpg
#   inflating: /content/batik/batik-bali/18.jpg
#   inflating: /content/batik/batik-bali/19.jpg
#   inflating: /content/batik/batik-bali/2.jpg
#   inflating: /content/batik/batik-bali/20.jpg
#   inflating: /content/batik/batik-bali/21.jpg
#   inflating: /content/batik/batik-bali/22.jpg
#   inflating: /content/batik/batik-bali/23.jpg
# ...

# %%
# !unzip -d /content/praktikum indonesian-abusive-and-hate-speech-twitter-text.zip
# Out:
# Archive:  indonesian-abusive-and-hate-speech-twitter-text.zip
#   inflating: /content/praktikum/README.md
#   inflating: /content/praktikum/abusive.csv
#   inflating: /content/praktikum/citation.bib
#   inflating: /content/praktikum/data.csv
#   inflating: /content/praktikum/new_kamusalay.csv

# %%
# !find /content/batik/ -type d -delete

# %%
import pandas as pd
import numpy as np
path="/content/praktikum/abusive.csv"
dataset=pd.read_csv(path)
dataset
# Out:
#          ABUSIVE
# 0           alay
# 1          ampas
# 2           buta
# 3        keparat
# 4         anjing
# ..           ...
# 120        rezim
# 121        sange
# 122       serbet
# 123        sipit
# 124  transgender
#
# [125 rows x 1 columns]

# %%
dataset.head()
# Out:
#    ABUSIVE
# 0     alay
# 1    ampas
# 2     buta
# 3  keparat
# 4   anjing

# %%
dataset.dtypes
# Out:
# ABUSIVE    object
# dtype: object
