# %% [markdown]
# <a href="https://colab.research.google.com/github/FarrelFach/Machine-Learning/blob/main/uts_DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

path="/content/drive/MyDrive/Machine_Learning/dataset_uts-2021.csv"
df=pd.read_csv(path)
df
# Out:
#    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 2   3      Luna Knox     PO.BOX 12-Loren Park           NaN       NaN
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6   7     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 7   8            XYS        Street 12 New Way           0.0       NaN
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2    luna@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 7              NaN
# 8   erica@text.com

# %%
df.isnull().sum()
# Out:
# No              0
# Name            0
# Address         0
# Mobile Phone    0
# Project         0
# Email           0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 2   3      Luna Knox     PO.BOX 12-Loren Park           NaN       NaN
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6   7     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 7   8            XYS        Street 12 New Way           0.0       NaN
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2    luna@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 7              NaN
# 8   erica@text.com  >

# %%
df.dtypes
# Out:
# No                int64
# Name             object
# Address          object
# Mobile Phone    float64
# Project          object
# Email            object
# dtype: object

# %%
df.dropna(axis=0, subset=['Mobile Phone','Project','Email'], inplace=True)

# %%
df
# Out:
#    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6   7     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 8   erica@text.com

# %%
df=df.drop(columns='No')

# %%
df.loc[4, 'Project'] = 'Internal'

# %%
df
# Out:
#             Nama                   Alamat Nomor Handphone    Proyek  \
# 0    Princy Odom        Street 1 New Lane     789456120.0    Client
# 1     Appy Alexa                Ac Street     568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road     123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street     789821211.0  Internal
# 5    August Bork  PO.BOX 17-Thames Street     125921931.0  Internal
# 6     Riley Drew  PO.BOX 16-Thames Street     789821211.0  Internal
# 8    Erica Flint   Street 7 New Lane Road     789456128.0  Internal
#
#              Surel   Project
# 0  princy@text.com       NaN
# 1    appy@text.com       NaN
# 3   clark@text.com       NaN
# 4   riley@text.com  Internal
# 5     aug@text.com       NaN
# 6   riley@text.com       NaN
# 8   erica@text.com       NaN

# %%
df['Mobile Phone']=df['Mobile Phone'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mobile Phone'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.dtypes
# Out:
# Nama               object
# Alamat             object
# Nomor Handphone    object
# Proyek             object
# Surel              object
# Project            object
# dtype: object

# %%
df.rename(columns = {'Name':'Nama', 'Address':'Alamat', 'Mobile Phone':'Nomor Handphone', 'Project':'Proyek', 'Email':'Surel'}, inplace = True)

# %%
df
# Out:
#             Nama                   Alamat Nomor Handphone    Proyek  \
# 0    Princy Odom        Street 1 New Lane     789456120.0    Client
# 1     Appy Alexa                Ac Street     568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road     123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street     789821211.0  Internal
# 5    August Bork  PO.BOX 17-Thames Street     125921931.0  Internal
# 6     Riley Drew  PO.BOX 16-Thames Street     789821211.0  Internal
# 8    Erica Flint   Street 7 New Lane Road     789456128.0  Internal
#
#              Surel   Project
# 0  princy@text.com       NaN
# 1    appy@text.com       NaN
# 3   clark@text.com       NaN
# 4   riley@text.com  Internal
# 5     aug@text.com       NaN
# 6   riley@text.com       NaN
# 8   erica@text.com       NaN

# %%
df.to_csv('/content/drive/MyDrive/Machine_Learning/data_uts_bersih.csv')
df1=pd.read_csv('/content/drive/MyDrive/Machine_Learning/data_uts_bersih.csv')
df1.head()
# Out:
#    Unnamed: 0           Nama                   Alamat  Nomor Handphone  \
# 0           0    Princy Odom        Street 1 New Lane      789456120.0
# 1           1     Appy Alexa                Ac Street      568798821.0
# 2           3  Clark Andrews   PO.BOX 156-Settle Road      123545342.0
# 3           4     Riley Drew  PO.BOX 16-Thames Street      789821211.0
# 4           5    August Bork  PO.BOX 17-Thames Street      125921931.0
#
#      Proyek            Surel   Project
# 0    Client  princy@text.com       NaN
# 1    Client    appy@text.com       NaN
# 2    Client   clark@text.com       NaN
# 3  Internal   riley@text.com  Internal
# 4  Internal     aug@text.com       NaN
