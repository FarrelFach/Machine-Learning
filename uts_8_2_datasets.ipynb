# %% [markdown]
# <a href="https://colab.research.google.com/github/FarrelFach/Machine-Learning/blob/main/uts_8_2_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

path="/content/drive/MyDrive/Machine_Learning/UTS_datasets.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0                      id  \
# 0           0  5ueyLj6e6oVaTY0KQ6yLaA
# 1           1  3aEJMh1cXKEjgh52claxQp
# 2           2  2vSxjnyrWrtxyfzO47EX6q
# 3           3  5yQ9iMZXGcr5rlO4hoLsP4
# 4           4  3HuJDcOWx0gE9Yng2uWY7K
#
#                                            name          artists  duration_ms  \
# 0                                  All Shook Up    Elvis Presley       117080
# 1  I've Got You Under My Skin - Remastered 1998    Frank Sinatra       223760
# 2                       Smoke Gets In Your Eyes     The Platters       160933
# 3                       What'd I Say, Pt. 1 & 2      Ray Charles       307053
# 4                    Dream A Little Dream Of Me  Louis Armstrong       196840
#
#    popularity  explicit                                  available_markets  \
# 0          61     False  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...
# 1          68     False  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...
# ...

# %% [markdown]
# Sumber Datasets:https://www.kaggle.com/datasets/tamle507/spotify-all-out-playlists-songs-1950s-2010s

# %%
import random
random.seed(123)
ind=np.random.choice([1, 2], size=(len(df['id'])), p=[0.8, 0.2])
ind
# Out:
# array([2, 2, 1, ..., 1, 1, 1])

# %%
train= df.loc[ind==1,]
train
# Out:
#       Unnamed: 0                      id                            name  \
# 2              2  2vSxjnyrWrtxyfzO47EX6q         Smoke Gets In Your Eyes
# 3              3  5yQ9iMZXGcr5rlO4hoLsP4         What'd I Say, Pt. 1 & 2
# 4              4  3HuJDcOWx0gE9Yng2uWY7K      Dream A Little Dream Of Me
# 5              5  50RwvvEKX5Q7AZt8FTAwIF              That'll Be The Day
# 6              6  01u6AEzGbGbQyYVdxajxqk                  Don't Be Cruel
# ...          ...                     ...                             ...
# 1044        1044  60nZcImufyMA1MKQY3dcCH  Happy - From "Despicable Me 2"
# 1046        1046  1DunhgeZSEgWiIYbHqXl0c                           Latch
# 1047        1047  6gU9OKjOE7ghfEd55oRO57                     The Weekend
# 1048        1048  6hkOqJ5mE093AQf2lbZnsG           The One That Got Away
# 1049        1049  4z7gh3aIZV9arbL9jJSc5J                           Ghost
#
#                     artists  duration_ms  popularity  explicit  \
# ...

# %%
test = df.loc[ind==2,]
test
# Out:
#       Unnamed: 0                      id  \
# 0              0  5ueyLj6e6oVaTY0KQ6yLaA
# 1              1  3aEJMh1cXKEjgh52claxQp
# 10            10  3YdKJzcoMZMacISlpY4QoP
# 19            19  4uxsv9PjV3Yeyn51RdWvGJ
# 21            21  1oDCK7PW72XEZ1pE5rh87A
# ...          ...                     ...
# 1017        1017  6TaqooOXAEcijL6G1AWS2K
# 1030        1030  0VwNdo84DaVYLIkbVO86ND
# 1031        1031  4nVBt6MZDDP6tRVdQTgxJg
# 1037        1037  0rTV5WefWd1J3OwIheTzxM
# 1045        1045  2VvCoqF4p46cvyVbhbDsaJ
#
#                                                    name  \
# 0                                          All Shook Up
# 1          I've Got You Under My Skin - Remastered 1998
# 10                             I Only Have Eyes for You
# 19                                                Misty
# 21                                                Smile
# ...                                                 ...
# 1017  All My Friends (feat. Tinashe & Chance the Rap...
# ...

# %%
train.head()
# Out:
#    Unnamed: 0                      id                        name  \
# 2           2  2vSxjnyrWrtxyfzO47EX6q     Smoke Gets In Your Eyes
# 3           3  5yQ9iMZXGcr5rlO4hoLsP4     What'd I Say, Pt. 1 & 2
# 4           4  3HuJDcOWx0gE9Yng2uWY7K  Dream A Little Dream Of Me
# 5           5  50RwvvEKX5Q7AZt8FTAwIF          That'll Be The Day
# 6           6  01u6AEzGbGbQyYVdxajxqk              Don't Be Cruel
#
#            artists  duration_ms  popularity  explicit  \
# 2     The Platters       160933          64     False
# 3      Ray Charles       307053          61     False
# 4  Louis Armstrong       196840          65     False
# 5      Buddy Holly       150133          61     False
# 6    Elvis Presley       122893          57     False
#
#                                    available_markets              add_date  \
# 2  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...  2022-06-09T22:02:00Z
# 3  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...  2022-06-09T22:02:00Z
# ...

# %%
test.head()
# Out:
#     Unnamed: 0                      id  \
# 0            0  5ueyLj6e6oVaTY0KQ6yLaA
# 1            1  3aEJMh1cXKEjgh52claxQp
# 10          10  3YdKJzcoMZMacISlpY4QoP
# 19          19  4uxsv9PjV3Yeyn51RdWvGJ
# 21          21  1oDCK7PW72XEZ1pE5rh87A
#
#                                             name        artists  duration_ms  \
# 0                                   All Shook Up  Elvis Presley       117080
# 1   I've Got You Under My Skin - Remastered 1998  Frank Sinatra       223760
# 10                      I Only Have Eyes for You  The Flamingos       202773
# 19                                         Misty  Johnny Mathis       216573
# 21                                         Smile  Nat King Cole       173266
#
#     popularity  explicit                                  available_markets  \
# 0           61     False  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...
# 1           68     False  AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB...
# ...
